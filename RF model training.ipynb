# %%
import pandas as pd 
import numpy as np
#import math

# %%
X_train = pd.read_csv('X_train.csv')
X_valid = pd.read_csv('X_valid.csv')
y_train = pd.read_csv('y_train.csv')
y_valid = pd.read_csv('y_valid.csv')

# %%
#concatenate training + validation sets 
X = pd.concat([X_train, X_valid])
y = pd.concat([y_train, y_valid])

# %%
X = X.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis = 1)
y = y.drop('Unnamed: 0', axis = 1)

# %%
X.head()
# Out:
#   item_type      utc_date country_code  item_price currency  numTracks  \
# 0         a  1.599956e+09           au       2.184      AUD        6.0
# 1         t  1.600334e+09           nz       1.300      GBP        1.0
# 2         a  1.600598e+09           de       0.000      USD        3.0
# 3         a  1.601296e+09           nz       0.000      USD       25.0
# 4         a  1.601310e+09           fr       0.000      USD        6.0
#
#    dateModified  datePublished  albumRelease         Genre inAlbum   tags
# 0  1.305590e+09   1.305518e+09             1          rock      is  other
# 1  1.574759e+09   1.574760e+09             1    electronic      in  house
# 2  1.376506e+09   1.359491e+09             1    electronic      is    80s
# 3  1.606288e+09   1.567251e+09             1  experimental      is  disco
# 4  1.586739e+09   1.413672e+09             1         metal      is  other

# %%
import datetime

# %%
utc_datetime = [datetime.datetime.utcfromtimestamp(x) for x in X['utc_date']]
day_month_year = [y.strftime("%a/%d") for y in utc_datetime]

# %%
#Bandcamp friday: first friday of the week
fridays = ['Fri/01', 'Fri/02', 'Fri/03', 'Fri/04', 'Fri/05', 'Fri/06', 'Fri/07']

# %%
BC_fridays = [1 if day in fridays else 0 for day in day_month_year]

# %%
X['BC_fridays'] = BC_fridays
X = X.drop(['utc_date', 'dateModified', 'datePublished'], axis = 1)

# %%
X.columns
# Out:
# Index(['item_type', 'country_code', 'item_price', 'currency', 'numTracks',
#        'albumRelease', 'Genre', 'inAlbum', 'tags', 'BC_fridays'],
#       dtype='object')

# %%
num_cols = ['item_price', 'numTracks', 'albumRelease']

# %%
for c in num_cols:
    X[c] = (X[c] - np.mean(X[c])) / np.std(X[c])

# %%
X.head()
# Out:
#   item_type country_code  item_price currency  numTracks  albumRelease  \
# 0         a           au   -0.486443      AUD  -0.029680      -0.37912
# 1         t           nz   -0.725651      GBP  -0.515869      -0.37912
# 2         a           de   -1.077429      USD  -0.321394      -0.37912
# 3         a           nz   -1.077429      USD   1.817836      -0.37912
# 4         a           fr   -1.077429      USD  -0.029680      -0.37912
#
#           Genre inAlbum   tags  BC_fridays
# 0          rock      is  other           0
# 1    electronic      in  house           0
# 2    electronic      is    80s           0
# 3  experimental      is  disco           0
# 4         metal      is  other           0

# %%
X_d = pd.get_dummies(X)

# %%
X_d.shape, y.shape
# Out:
# ((483876, 258), (483876, 1))

# %%
y = y['amount_paid_usd']
y = (y - np.mean(y))/ np.std(y)

# %% [markdown]
# #### random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV

# %%
rfr = RandomForestRegressor(random_state = 42)

# %%
parameters = {'n_estimators' : np.array([25, 50, 100, 200, 500]),
              'min_samples_split': np.array([1, 5, 10]),
              'max_features':np.array([0.3, 0.5, 0.8, 1])}

# %%
hyp_search = GridSearchCV(estimator = rfr, 
                          param_grid = parameters, 
                          cv = 5, 
                         verbose = 10,
                         scoring = 'neg_root_mean_squared_error')

# %%
# %%time
hyp_search.fit(X_d, y)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV 1/5; 1/60] START max_features=0.3, min_samples_split=1, n_estimators=25.....
# [CV 1/5; 1/60] END max_features=0.3, min_samples_split=1, n_estimators=25;, score=-0.538 total time= 1.8min
# [CV 2/5; 1/60] START max_features=0.3, min_samples_split=1, n_estimators=25.....
# [CV 2/5; 1/60] END max_features=0.3, min_samples_split=1, n_estimators=25;, score=-0.538 total time= 1.9min
# [CV 3/5; 1/60] START max_features=0.3, min_samples_split=1, n_estimators=25.....
# [CV 3/5; 1/60] END max_features=0.3, min_samples_split=1, n_estimators=25;, score=-0.535 total time= 1.8min
# [CV 4/5; 1/60] START max_features=0.3, min_samples_split=1, n_estimators=25.....
# [CV 4/5; 1/60] END max_features=0.3, min_samples_split=1, n_estimators=25;, score=-0.539 total time= 1.8min
# [CV 5/5; 1/60] START max_features=0.3, min_samples_split=1, n_estimators=25.....
# [CV 5/5; 1/60] END max_features=0.3, min_samples_split=1, n_estimators=25;, score=-0.539 total time= 1.8min
# [CV 1/5; 2/60] START max_features=0.3, min_samples_split=1, n_estimators=50.....
# [CV 1/5; 2/60] END max_features=0.3, min_samples_split=1, n_estimators=50;, score=-0.536 total time= 3.5min
# [CV 2/5; 2/60] START max_features=0.3, min_samples_split=1, n_estimators=50.....
# [CV 2/5; 2/60] END max_features=0.3, min_samples_split=1, n_estimators=50;, score=-0.536 total time= 3.6min
# [CV 3/5; 2/60] START max_features=0.3, min_samples_split=1, n_estimators=50.....
# [CV 3/5; 2/60] END max_features=0.3, min_samples_split=1, n_estimators=50;, score=-0.533 total time= 3.7min
# [CV 4/5; 2/60] START max_features=0.3, min_samples_split=1, n_estimators=50.....
# [CV 4/5; 2/60] END max_features=0.3, min_samples_split=1, n_estimators=50;, score=-0.538 total time= 3.6min
# [CV 5/5; 2/60] START max_features=0.3, min_samples_split=1, n_estimators=50.....
# [CV 5/5; 2/60] END max_features=0.3, min_samples_split=1, n_estimators=50;, score=-0.537 total time= 3.7min
# [CV 1/5; 3/60] START max_features=0.3, min_samples_split=1, n_estimators=100....
# [CV 1/5; 3/60] END max_features=0.3, min_samples_split=1, n_estimators=100;, score=-0.535 total time= 7.3min
# [CV 2/5; 3/60] START max_features=0.3, min_samples_split=1, n_estimators=100....
# [CV 2/5; 3/60] END max_features=0.3, min_samples_split=1, n_estimators=100;, score=-0.536 total time= 7.3min
# [CV 3/5; 3/60] START max_features=0.3, min_samples_split=1, n_estimators=100....
# [CV 3/5; 3/60] END max_features=0.3, min_samples_split=1, n_estimators=100;, score=-0.532 total time= 7.4min
# [CV 4/5; 3/60] START max_features=0.3, min_samples_split=1, n_estimators=100....
# [CV 4/5; 3/60] END max_features=0.3, min_samples_split=1, n_estimators=100;, score=-0.537 total time= 7.4min
# [CV 5/5; 3/60] START max_features=0.3, min_samples_split=1, n_estimators=100....
# [CV 5/5; 3/60] END max_features=0.3, min_samples_split=1, n_estimators=100;, score=-0.536 total time= 7.5min
# [CV 1/5; 4/60] START max_features=0.3, min_samples_split=1, n_estimators=200....
# [CV 1/5; 4/60] END max_features=0.3, min_samples_split=1, n_estimators=200;, score=-0.534 total time=15.0min
# [CV 2/5; 4/60] START max_features=0.3, min_samples_split=1, n_estimators=200....
# [CV 2/5; 4/60] END max_features=0.3, min_samples_split=1, n_estimators=200;, score=-0.535 total time=15.4min
# [CV 3/5; 4/60] START max_features=0.3, min_samples_split=1, n_estimators=200....
# [CV 3/5; 4/60] END max_features=0.3, min_samples_split=1, n_estimators=200;, score=-0.532 total time=15.5min
# [CV 4/5; 4/60] START max_features=0.3, min_samples_split=1, n_estimators=200....
# [CV 4/5; 4/60] END max_features=0.3, min_samples_split=1, n_estimators=200;, score=-0.536 total time=15.9min
# [CV 5/5; 4/60] START max_features=0.3, min_samples_split=1, n_estimators=200....
# [CV 5/5; 4/60] END max_features=0.3, min_samples_split=1, n_estimators=200;, score=-0.535 total time=15.8min
# [CV 1/5; 5/60] START max_features=0.3, min_samples_split=1, n_estimators=500....
# [CV 1/5; 5/60] END max_features=0.3, min_samples_split=1, n_estimators=500;, score=-0.534 total time=38.6min
# [CV 2/5; 5/60] START max_features=0.3, min_samples_split=1, n_estimators=500....
# [CV 2/5; 5/60] END max_features=0.3, min_samples_split=1, n_estimators=500;, score=-0.535 total time=38.7min
# [CV 3/5; 5/60] START max_features=0.3, min_samples_split=1, n_estimators=500....
# [CV 3/5; 5/60] END max_features=0.3, min_samples_split=1, n_estimators=500;, score=-0.531 total time=38.6min
# [CV 4/5; 5/60] START max_features=0.3, min_samples_split=1, n_estimators=500....
# [CV 4/5; 5/60] END max_features=0.3, min_samples_split=1, n_estimators=500;, score=-0.536 total time=38.6min
# [CV 5/5; 5/60] START max_features=0.3, min_samples_split=1, n_estimators=500....
# [CV 5/5; 5/60] END max_features=0.3, min_samples_split=1, n_estimators=500;, score=-0.535 total time=38.8min
# [CV 1/5; 6/60] START max_features=0.3, min_samples_split=5, n_estimators=25.....
# [CV 1/5; 6/60] END max_features=0.3, min_samples_split=5, n_estimators=25;, score=-0.529 total time= 1.9min
# [CV 2/5; 6/60] START max_features=0.3, min_samples_split=5, n_estimators=25.....
# [CV 2/5; 6/60] END max_features=0.3, min_samples_split=5, n_estimators=25;, score=-0.529 total time= 1.9min
# [CV 3/5; 6/60] START max_features=0.3, min_samples_split=5, n_estimators=25.....
# [CV 3/5; 6/60] END max_features=0.3, min_samples_split=5, n_estimators=25;, score=-0.527 total time= 1.9min
# [CV 4/5; 6/60] START max_features=0.3, min_samples_split=5, n_estimators=25.....
# [CV 4/5; 6/60] END max_features=0.3, min_samples_split=5, n_estimators=25;, score=-0.530 total time= 1.9min
# [CV 5/5; 6/60] START max_features=0.3, min_samples_split=5, n_estimators=25.....
# [CV 5/5; 6/60] END max_features=0.3, min_samples_split=5, n_estimators=25;, score=-0.530 total time= 1.9min
# [CV 1/5; 7/60] START max_features=0.3, min_samples_split=5, n_estimators=50.....
# [CV 1/5; 7/60] END max_features=0.3, min_samples_split=5, n_estimators=50;, score=-0.527 total time= 3.7min
# [CV 2/5; 7/60] START max_features=0.3, min_samples_split=5, n_estimators=50.....
# [CV 2/5; 7/60] END max_features=0.3, min_samples_split=5, n_estimators=50;, score=-0.528 total time= 3.7min
# [CV 3/5; 7/60] START max_features=0.3, min_samples_split=5, n_estimators=50.....
# [CV 3/5; 7/60] END max_features=0.3, min_samples_split=5, n_estimators=50;, score=-0.525 total time= 3.7min
# [CV 4/5; 7/60] START max_features=0.3, min_samples_split=5, n_estimators=50.....
# [CV 4/5; 7/60] END max_features=0.3, min_samples_split=5, n_estimators=50;, score=-0.529 total time= 3.7min
# [CV 5/5; 7/60] START max_features=0.3, min_samples_split=5, n_estimators=50.....
# [CV 5/5; 7/60] END max_features=0.3, min_samples_split=5, n_estimators=50;, score=-0.528 total time= 3.7min
# [CV 1/5; 8/60] START max_features=0.3, min_samples_split=5, n_estimators=100....
# [CV 1/5; 8/60] END max_features=0.3, min_samples_split=5, n_estimators=100;, score=-0.526 total time= 7.4min
# [CV 2/5; 8/60] START max_features=0.3, min_samples_split=5, n_estimators=100....
# [CV 2/5; 8/60] END max_features=0.3, min_samples_split=5, n_estimators=100;, score=-0.527 total time= 7.5min
# [CV 3/5; 8/60] START max_features=0.3, min_samples_split=5, n_estimators=100....
# [CV 3/5; 8/60] END max_features=0.3, min_samples_split=5, n_estimators=100;, score=-0.524 total time= 7.4min
# [CV 4/5; 8/60] START max_features=0.3, min_samples_split=5, n_estimators=100....
# [CV 4/5; 8/60] END max_features=0.3, min_samples_split=5, n_estimators=100;, score=-0.528 total time= 7.4min
# [CV 5/5; 8/60] START max_features=0.3, min_samples_split=5, n_estimators=100....
# [CV 5/5; 8/60] END max_features=0.3, min_samples_split=5, n_estimators=100;, score=-0.527 total time= 7.4min
# [CV 1/5; 9/60] START max_features=0.3, min_samples_split=5, n_estimators=200....
# [CV 1/5; 9/60] END max_features=0.3, min_samples_split=5, n_estimators=200;, score=-0.526 total time=14.7min
# [CV 2/5; 9/60] START max_features=0.3, min_samples_split=5, n_estimators=200....
# [CV 2/5; 9/60] END max_features=0.3, min_samples_split=5, n_estimators=200;, score=-0.527 total time=14.9min
# [CV 3/5; 9/60] START max_features=0.3, min_samples_split=5, n_estimators=200....
# [CV 3/5; 9/60] END max_features=0.3, min_samples_split=5, n_estimators=200;, score=-0.524 total time=14.9min
# [CV 4/5; 9/60] START max_features=0.3, min_samples_split=5, n_estimators=200....
# [CV 4/5; 9/60] END max_features=0.3, min_samples_split=5, n_estimators=200;, score=-0.528 total time=14.8min
# [CV 5/5; 9/60] START max_features=0.3, min_samples_split=5, n_estimators=200....
# [CV 5/5; 9/60] END max_features=0.3, min_samples_split=5, n_estimators=200;, score=-0.527 total time=14.7min
# [CV 1/5; 10/60] START max_features=0.3, min_samples_split=5, n_estimators=500...
# [CV 1/5; 10/60] END max_features=0.3, min_samples_split=5, n_estimators=500;, score=-0.526 total time=36.9min
# [CV 2/5; 10/60] START max_features=0.3, min_samples_split=5, n_estimators=500...
# [CV 2/5; 10/60] END max_features=0.3, min_samples_split=5, n_estimators=500;, score=-0.527 total time=37.7min
# [CV 3/5; 10/60] START max_features=0.3, min_samples_split=5, n_estimators=500...
# [CV 3/5; 10/60] END max_features=0.3, min_samples_split=5, n_estimators=500;, score=-0.524 total time=37.9min
# [CV 4/5; 10/60] START max_features=0.3, min_samples_split=5, n_estimators=500...
# [CV 4/5; 10/60] END max_features=0.3, min_samples_split=5, n_estimators=500;, score=-0.528 total time=37.4min
# [CV 5/5; 10/60] START max_features=0.3, min_samples_split=5, n_estimators=500...
# [CV 5/5; 10/60] END max_features=0.3, min_samples_split=5, n_estimators=500;, score=-0.527 total time=37.5min
# [CV 1/5; 11/60] START max_features=0.3, min_samples_split=10, n_estimators=25...
# [CV 1/5; 11/60] END max_features=0.3, min_samples_split=10, n_estimators=25;, score=-0.524 total time= 1.8min
# [CV 2/5; 11/60] START max_features=0.3, min_samples_split=10, n_estimators=25...
# [CV 2/5; 11/60] END max_features=0.3, min_samples_split=10, n_estimators=25;, score=-0.524 total time= 1.8min
# [CV 3/5; 11/60] START max_features=0.3, min_samples_split=10, n_estimators=25...
# [CV 3/5; 11/60] END max_features=0.3, min_samples_split=10, n_estimators=25;, score=-0.521 total time= 1.9min
# [CV 4/5; 11/60] START max_features=0.3, min_samples_split=10, n_estimators=25...
# [CV 4/5; 11/60] END max_features=0.3, min_samples_split=10, n_estimators=25;, score=-0.526 total time= 1.9min
# [CV 5/5; 11/60] START max_features=0.3, min_samples_split=10, n_estimators=25...
# [CV 5/5; 11/60] END max_features=0.3, min_samples_split=10, n_estimators=25;, score=-0.525 total time= 1.8min
# [CV 1/5; 12/60] START max_features=0.3, min_samples_split=10, n_estimators=50...
# [CV 1/5; 12/60] END max_features=0.3, min_samples_split=10, n_estimators=50;, score=-0.522 total time= 3.6min
# [CV 2/5; 12/60] START max_features=0.3, min_samples_split=10, n_estimators=50...
# [CV 2/5; 12/60] END max_features=0.3, min_samples_split=10, n_estimators=50;, score=-0.523 total time= 3.6min
# [CV 3/5; 12/60] START max_features=0.3, min_samples_split=10, n_estimators=50...
# [CV 3/5; 12/60] END max_features=0.3, min_samples_split=10, n_estimators=50;, score=-0.520 total time= 3.7min
# [CV 4/5; 12/60] START max_features=0.3, min_samples_split=10, n_estimators=50...
# [CV 4/5; 12/60] END max_features=0.3, min_samples_split=10, n_estimators=50;, score=-0.525 total time= 3.7min
# [CV 5/5; 12/60] START max_features=0.3, min_samples_split=10, n_estimators=50...
# [CV 5/5; 12/60] END max_features=0.3, min_samples_split=10, n_estimators=50;, score=-0.524 total time= 3.6min
# [CV 1/5; 13/60] START max_features=0.3, min_samples_split=10, n_estimators=100..
# [CV 1/5; 13/60] END max_features=0.3, min_samples_split=10, n_estimators=100;, score=-0.522 total time= 7.1min
# [CV 2/5; 13/60] START max_features=0.3, min_samples_split=10, n_estimators=100..
# [CV 2/5; 13/60] END max_features=0.3, min_samples_split=10, n_estimators=100;, score=-0.523 total time= 7.2min
# [CV 3/5; 13/60] START max_features=0.3, min_samples_split=10, n_estimators=100..
# [CV 3/5; 13/60] END max_features=0.3, min_samples_split=10, n_estimators=100;, score=-0.519 total time= 7.2min
# [CV 4/5; 13/60] START max_features=0.3, min_samples_split=10, n_estimators=100..
# [CV 4/5; 13/60] END max_features=0.3, min_samples_split=10, n_estimators=100;, score=-0.524 total time= 7.3min
# [CV 5/5; 13/60] START max_features=0.3, min_samples_split=10, n_estimators=100..
# [CV 5/5; 13/60] END max_features=0.3, min_samples_split=10, n_estimators=100;, score=-0.523 total time= 7.3min
# [CV 1/5; 14/60] START max_features=0.3, min_samples_split=10, n_estimators=200..
# [CV 1/5; 14/60] END max_features=0.3, min_samples_split=10, n_estimators=200;, score=-0.521 total time=14.4min
# [CV 2/5; 14/60] START max_features=0.3, min_samples_split=10, n_estimators=200..
# [CV 2/5; 14/60] END max_features=0.3, min_samples_split=10, n_estimators=200;, score=-0.522 total time=14.6min
# [CV 3/5; 14/60] START max_features=0.3, min_samples_split=10, n_estimators=200..
# [CV 3/5; 14/60] END max_features=0.3, min_samples_split=10, n_estimators=200;, score=-0.519 total time=14.4min
# [CV 4/5; 14/60] START max_features=0.3, min_samples_split=10, n_estimators=200..
# [CV 4/5; 14/60] END max_features=0.3, min_samples_split=10, n_estimators=200;, score=-0.524 total time=14.5min
# [CV 5/5; 14/60] START max_features=0.3, min_samples_split=10, n_estimators=200..
# [CV 5/5; 14/60] END max_features=0.3, min_samples_split=10, n_estimators=200;, score=-0.523 total time=14.4min
# [CV 1/5; 15/60] START max_features=0.3, min_samples_split=10, n_estimators=500..
# [CV 1/5; 15/60] END max_features=0.3, min_samples_split=10, n_estimators=500;, score=-0.521 total time=35.8min
# [CV 2/5; 15/60] START max_features=0.3, min_samples_split=10, n_estimators=500..
# [CV 2/5; 15/60] END max_features=0.3, min_samples_split=10, n_estimators=500;, score=-0.522 total time=36.1min
# [CV 3/5; 15/60] START max_features=0.3, min_samples_split=10, n_estimators=500..
# [CV 3/5; 15/60] END max_features=0.3, min_samples_split=10, n_estimators=500;, score=-0.519 total time=36.0min
# [CV 4/5; 15/60] START max_features=0.3, min_samples_split=10, n_estimators=500..
# [CV 4/5; 15/60] END max_features=0.3, min_samples_split=10, n_estimators=500;, score=-0.523 total time=36.1min
# [CV 5/5; 15/60] START max_features=0.3, min_samples_split=10, n_estimators=500..
# [CV 5/5; 15/60] END max_features=0.3, min_samples_split=10, n_estimators=500;, score=-0.523 total time=36.5min
# [CV 1/5; 16/60] START max_features=0.5, min_samples_split=1, n_estimators=25....
# [CV 1/5; 16/60] END max_features=0.5, min_samples_split=1, n_estimators=25;, score=-0.536 total time= 2.7min
# [CV 2/5; 16/60] START max_features=0.5, min_samples_split=1, n_estimators=25....
# [CV 2/5; 16/60] END max_features=0.5, min_samples_split=1, n_estimators=25;, score=-0.537 total time= 2.8min
# [CV 3/5; 16/60] START max_features=0.5, min_samples_split=1, n_estimators=25....
# [CV 3/5; 16/60] END max_features=0.5, min_samples_split=1, n_estimators=25;, score=-0.533 total time= 2.7min
# [CV 4/5; 16/60] START max_features=0.5, min_samples_split=1, n_estimators=25....
# [CV 4/5; 16/60] END max_features=0.5, min_samples_split=1, n_estimators=25;, score=-0.538 total time= 2.8min
# [CV 5/5; 16/60] START max_features=0.5, min_samples_split=1, n_estimators=25....
# [CV 5/5; 16/60] END max_features=0.5, min_samples_split=1, n_estimators=25;, score=-0.537 total time= 2.7min
# [CV 1/5; 17/60] START max_features=0.5, min_samples_split=1, n_estimators=50....
# [CV 1/5; 17/60] END max_features=0.5, min_samples_split=1, n_estimators=50;, score=-0.534 total time= 5.5min
# [CV 2/5; 17/60] START max_features=0.5, min_samples_split=1, n_estimators=50....
# [CV 2/5; 17/60] END max_features=0.5, min_samples_split=1, n_estimators=50;, score=-0.535 total time= 5.5min
# [CV 3/5; 17/60] START max_features=0.5, min_samples_split=1, n_estimators=50....
# [CV 3/5; 17/60] END max_features=0.5, min_samples_split=1, n_estimators=50;, score=-0.531 total time= 5.5min
# [CV 4/5; 17/60] START max_features=0.5, min_samples_split=1, n_estimators=50....
# [CV 4/5; 17/60] END max_features=0.5, min_samples_split=1, n_estimators=50;, score=-0.536 total time= 5.5min
# [CV 5/5; 17/60] START max_features=0.5, min_samples_split=1, n_estimators=50....
# [CV 5/5; 17/60] END max_features=0.5, min_samples_split=1, n_estimators=50;, score=-0.536 total time= 5.5min
# [CV 1/5; 18/60] START max_features=0.5, min_samples_split=1, n_estimators=100...
# [CV 1/5; 18/60] END max_features=0.5, min_samples_split=1, n_estimators=100;, score=-0.533 total time=10.9min
# [CV 2/5; 18/60] START max_features=0.5, min_samples_split=1, n_estimators=100...
# [CV 2/5; 18/60] END max_features=0.5, min_samples_split=1, n_estimators=100;, score=-0.534 total time=10.8min
# [CV 3/5; 18/60] START max_features=0.5, min_samples_split=1, n_estimators=100...
# [CV 3/5; 18/60] END max_features=0.5, min_samples_split=1, n_estimators=100;, score=-0.531 total time=10.9min
# [CV 4/5; 18/60] START max_features=0.5, min_samples_split=1, n_estimators=100...
# [CV 4/5; 18/60] END max_features=0.5, min_samples_split=1, n_estimators=100;, score=-0.535 total time=10.8min
# [CV 5/5; 18/60] START max_features=0.5, min_samples_split=1, n_estimators=100...
# [CV 5/5; 18/60] END max_features=0.5, min_samples_split=1, n_estimators=100;, score=-0.534 total time=10.8min
# [CV 1/5; 19/60] START max_features=0.5, min_samples_split=1, n_estimators=200...
# [CV 1/5; 19/60] END max_features=0.5, min_samples_split=1, n_estimators=200;, score=-0.533 total time=21.6min
# [CV 2/5; 19/60] START max_features=0.5, min_samples_split=1, n_estimators=200...
# [CV 2/5; 19/60] END max_features=0.5, min_samples_split=1, n_estimators=200;, score=-0.533 total time=21.5min
# [CV 3/5; 19/60] START max_features=0.5, min_samples_split=1, n_estimators=200...
# [CV 3/5; 19/60] END max_features=0.5, min_samples_split=1, n_estimators=200;, score=-0.530 total time=21.6min
# [CV 4/5; 19/60] START max_features=0.5, min_samples_split=1, n_estimators=200...
# [CV 4/5; 19/60] END max_features=0.5, min_samples_split=1, n_estimators=200;, score=-0.535 total time=21.9min
# [CV 5/5; 19/60] START max_features=0.5, min_samples_split=1, n_estimators=200...
# [CV 5/5; 19/60] END max_features=0.5, min_samples_split=1, n_estimators=200;, score=-0.534 total time=21.8min
# [CV 1/5; 20/60] START max_features=0.5, min_samples_split=1, n_estimators=500...
# [CV 1/5; 20/60] END max_features=0.5, min_samples_split=1, n_estimators=500;, score=-0.533 total time=54.0min
# [CV 2/5; 20/60] START max_features=0.5, min_samples_split=1, n_estimators=500...
# [CV 2/5; 20/60] END max_features=0.5, min_samples_split=1, n_estimators=500;, score=-0.533 total time=53.8min
# [CV 3/5; 20/60] START max_features=0.5, min_samples_split=1, n_estimators=500...
# [CV 3/5; 20/60] END max_features=0.5, min_samples_split=1, n_estimators=500;, score=-0.530 total time=53.6min
# [CV 4/5; 20/60] START max_features=0.5, min_samples_split=1, n_estimators=500...
# [CV 4/5; 20/60] END max_features=0.5, min_samples_split=1, n_estimators=500;, score=-0.534 total time=54.5min
# [CV 5/5; 20/60] START max_features=0.5, min_samples_split=1, n_estimators=500...
# [CV 5/5; 20/60] END max_features=0.5, min_samples_split=1, n_estimators=500;, score=-0.534 total time=55.3min
# [CV 1/5; 21/60] START max_features=0.5, min_samples_split=5, n_estimators=25....
# [CV 1/5; 21/60] END max_features=0.5, min_samples_split=5, n_estimators=25;, score=-0.527 total time= 2.7min
# [CV 2/5; 21/60] START max_features=0.5, min_samples_split=5, n_estimators=25....
# [CV 2/5; 21/60] END max_features=0.5, min_samples_split=5, n_estimators=25;, score=-0.528 total time= 2.8min
# [CV 3/5; 21/60] START max_features=0.5, min_samples_split=5, n_estimators=25....
# [CV 3/5; 21/60] END max_features=0.5, min_samples_split=5, n_estimators=25;, score=-0.525 total time= 2.7min
# [CV 4/5; 21/60] START max_features=0.5, min_samples_split=5, n_estimators=25....
# [CV 4/5; 21/60] END max_features=0.5, min_samples_split=5, n_estimators=25;, score=-0.529 total time= 2.8min
# [CV 5/5; 21/60] START max_features=0.5, min_samples_split=5, n_estimators=25....
# [CV 5/5; 21/60] END max_features=0.5, min_samples_split=5, n_estimators=25;, score=-0.529 total time= 2.7min
# [CV 1/5; 22/60] START max_features=0.5, min_samples_split=5, n_estimators=50....
# [CV 1/5; 22/60] END max_features=0.5, min_samples_split=5, n_estimators=50;, score=-0.526 total time= 5.5min
# [CV 2/5; 22/60] START max_features=0.5, min_samples_split=5, n_estimators=50....
# [CV 2/5; 22/60] END max_features=0.5, min_samples_split=5, n_estimators=50;, score=-0.527 total time= 5.5min
# [CV 3/5; 22/60] START max_features=0.5, min_samples_split=5, n_estimators=50....
# [CV 3/5; 22/60] END max_features=0.5, min_samples_split=5, n_estimators=50;, score=-0.524 total time= 5.4min
# [CV 4/5; 22/60] START max_features=0.5, min_samples_split=5, n_estimators=50....
# [CV 4/5; 22/60] END max_features=0.5, min_samples_split=5, n_estimators=50;, score=-0.528 total time= 5.4min
# [CV 5/5; 22/60] START max_features=0.5, min_samples_split=5, n_estimators=50....
# [CV 5/5; 22/60] END max_features=0.5, min_samples_split=5, n_estimators=50;, score=-0.527 total time= 5.5min
# [CV 1/5; 23/60] START max_features=0.5, min_samples_split=5, n_estimators=100...
# [CV 1/5; 23/60] END max_features=0.5, min_samples_split=5, n_estimators=100;, score=-0.525 total time=10.8min
# [CV 2/5; 23/60] START max_features=0.5, min_samples_split=5, n_estimators=100...
# [CV 2/5; 23/60] END max_features=0.5, min_samples_split=5, n_estimators=100;, score=-0.526 total time=10.9min
# [CV 3/5; 23/60] START max_features=0.5, min_samples_split=5, n_estimators=100...
# [CV 3/5; 23/60] END max_features=0.5, min_samples_split=5, n_estimators=100;, score=-0.523 total time=10.9min
# [CV 4/5; 23/60] START max_features=0.5, min_samples_split=5, n_estimators=100...
# [CV 4/5; 23/60] END max_features=0.5, min_samples_split=5, n_estimators=100;, score=-0.527 total time=10.8min
# [CV 5/5; 23/60] START max_features=0.5, min_samples_split=5, n_estimators=100...
# [CV 5/5; 23/60] END max_features=0.5, min_samples_split=5, n_estimators=100;, score=-0.526 total time=10.8min
# [CV 1/5; 24/60] START max_features=0.5, min_samples_split=5, n_estimators=200...
# [CV 1/5; 24/60] END max_features=0.5, min_samples_split=5, n_estimators=200;, score=-0.525 total time=21.7min
# [CV 2/5; 24/60] START max_features=0.5, min_samples_split=5, n_estimators=200...
# [CV 2/5; 24/60] END max_features=0.5, min_samples_split=5, n_estimators=200;, score=-0.526 total time=21.8min
# [CV 3/5; 24/60] START max_features=0.5, min_samples_split=5, n_estimators=200...
# [CV 3/5; 24/60] END max_features=0.5, min_samples_split=5, n_estimators=200;, score=-0.523 total time=21.8min
# [CV 4/5; 24/60] START max_features=0.5, min_samples_split=5, n_estimators=200...
# [CV 4/5; 24/60] END max_features=0.5, min_samples_split=5, n_estimators=200;, score=-0.527 total time=21.8min
# [CV 5/5; 24/60] START max_features=0.5, min_samples_split=5, n_estimators=200...
# [CV 5/5; 24/60] END max_features=0.5, min_samples_split=5, n_estimators=200;, score=-0.526 total time=22.0min
# [CV 1/5; 25/60] START max_features=0.5, min_samples_split=5, n_estimators=500...
# [CV 1/5; 25/60] END max_features=0.5, min_samples_split=5, n_estimators=500;, score=-0.525 total time=54.4min
# [CV 2/5; 25/60] START max_features=0.5, min_samples_split=5, n_estimators=500...
# [CV 2/5; 25/60] END max_features=0.5, min_samples_split=5, n_estimators=500;, score=-0.526 total time=54.3min
# [CV 3/5; 25/60] START max_features=0.5, min_samples_split=5, n_estimators=500...
# [CV 3/5; 25/60] END max_features=0.5, min_samples_split=5, n_estimators=500;, score=-0.523 total time=53.7min
# [CV 4/5; 25/60] START max_features=0.5, min_samples_split=5, n_estimators=500...
# [CV 4/5; 25/60] END max_features=0.5, min_samples_split=5, n_estimators=500;, score=-0.527 total time=53.7min
# [CV 5/5; 25/60] START max_features=0.5, min_samples_split=5, n_estimators=500...
# [CV 5/5; 25/60] END max_features=0.5, min_samples_split=5, n_estimators=500;, score=-0.526 total time=54.2min
# [CV 1/5; 26/60] START max_features=0.5, min_samples_split=10, n_estimators=25...
# [CV 1/5; 26/60] END max_features=0.5, min_samples_split=10, n_estimators=25;, score=-0.523 total time= 2.7min
# [CV 2/5; 26/60] START max_features=0.5, min_samples_split=10, n_estimators=25...
# [CV 2/5; 26/60] END max_features=0.5, min_samples_split=10, n_estimators=25;, score=-0.524 total time= 2.7min
# [CV 3/5; 26/60] START max_features=0.5, min_samples_split=10, n_estimators=25...
# [CV 3/5; 26/60] END max_features=0.5, min_samples_split=10, n_estimators=25;, score=-0.520 total time= 2.7min
# [CV 4/5; 26/60] START max_features=0.5, min_samples_split=10, n_estimators=25...
# [CV 4/5; 26/60] END max_features=0.5, min_samples_split=10, n_estimators=25;, score=-0.525 total time= 2.7min
# [CV 5/5; 26/60] START max_features=0.5, min_samples_split=10, n_estimators=25...
# [CV 5/5; 26/60] END max_features=0.5, min_samples_split=10, n_estimators=25;, score=-0.525 total time= 2.7min
# [CV 1/5; 27/60] START max_features=0.5, min_samples_split=10, n_estimators=50...
# [CV 1/5; 27/60] END max_features=0.5, min_samples_split=10, n_estimators=50;, score=-0.522 total time= 5.4min
# [CV 2/5; 27/60] START max_features=0.5, min_samples_split=10, n_estimators=50...
# [CV 2/5; 27/60] END max_features=0.5, min_samples_split=10, n_estimators=50;, score=-0.523 total time= 5.4min
# [CV 3/5; 27/60] START max_features=0.5, min_samples_split=10, n_estimators=50...
# [CV 3/5; 27/60] END max_features=0.5, min_samples_split=10, n_estimators=50;, score=-0.519 total time= 5.4min
# [CV 4/5; 27/60] START max_features=0.5, min_samples_split=10, n_estimators=50...
# [CV 4/5; 27/60] END max_features=0.5, min_samples_split=10, n_estimators=50;, score=-0.524 total time= 5.4min
# [CV 5/5; 27/60] START max_features=0.5, min_samples_split=10, n_estimators=50...
# [CV 5/5; 27/60] END max_features=0.5, min_samples_split=10, n_estimators=50;, score=-0.523 total time= 5.4min
# [CV 1/5; 28/60] START max_features=0.5, min_samples_split=10, n_estimators=100..
# [CV 1/5; 28/60] END max_features=0.5, min_samples_split=10, n_estimators=100;, score=-0.521 total time=10.7min
# [CV 2/5; 28/60] START max_features=0.5, min_samples_split=10, n_estimators=100..
# [CV 2/5; 28/60] END max_features=0.5, min_samples_split=10, n_estimators=100;, score=-0.522 total time=10.7min
# [CV 3/5; 28/60] START max_features=0.5, min_samples_split=10, n_estimators=100..
# [CV 3/5; 28/60] END max_features=0.5, min_samples_split=10, n_estimators=100;, score=-0.518 total time=10.8min
# [CV 4/5; 28/60] START max_features=0.5, min_samples_split=10, n_estimators=100..
# [CV 4/5; 28/60] END max_features=0.5, min_samples_split=10, n_estimators=100;, score=-0.523 total time=10.8min
# [CV 5/5; 28/60] START max_features=0.5, min_samples_split=10, n_estimators=100..
# [CV 5/5; 28/60] END max_features=0.5, min_samples_split=10, n_estimators=100;, score=-0.522 total time=10.7min
# [CV 1/5; 29/60] START max_features=0.5, min_samples_split=10, n_estimators=200..
# [CV 1/5; 29/60] END max_features=0.5, min_samples_split=10, n_estimators=200;, score=-0.521 total time=21.3min
# [CV 2/5; 29/60] START max_features=0.5, min_samples_split=10, n_estimators=200..
# [CV 2/5; 29/60] END max_features=0.5, min_samples_split=10, n_estimators=200;, score=-0.521 total time=21.6min
# [CV 3/5; 29/60] START max_features=0.5, min_samples_split=10, n_estimators=200..
# [CV 3/5; 29/60] END max_features=0.5, min_samples_split=10, n_estimators=200;, score=-0.518 total time=21.4min
# [CV 4/5; 29/60] START max_features=0.5, min_samples_split=10, n_estimators=200..
# [CV 4/5; 29/60] END max_features=0.5, min_samples_split=10, n_estimators=200;, score=-0.523 total time=21.3min
# [CV 5/5; 29/60] START max_features=0.5, min_samples_split=10, n_estimators=200..
# [CV 5/5; 29/60] END max_features=0.5, min_samples_split=10, n_estimators=200;, score=-0.522 total time=21.4min
# [CV 1/5; 30/60] START max_features=0.5, min_samples_split=10, n_estimators=500..
# [CV 1/5; 30/60] END max_features=0.5, min_samples_split=10, n_estimators=500;, score=-0.520 total time=52.9min
# [CV 2/5; 30/60] START max_features=0.5, min_samples_split=10, n_estimators=500..
# [CV 2/5; 30/60] END max_features=0.5, min_samples_split=10, n_estimators=500;, score=-0.521 total time=53.0min
# [CV 3/5; 30/60] START max_features=0.5, min_samples_split=10, n_estimators=500..
# [CV 3/5; 30/60] END max_features=0.5, min_samples_split=10, n_estimators=500;, score=-0.517 total time=53.0min
# [CV 4/5; 30/60] START max_features=0.5, min_samples_split=10, n_estimators=500..
# [CV 4/5; 30/60] END max_features=0.5, min_samples_split=10, n_estimators=500;, score=-0.523 total time=53.2min
# [CV 5/5; 30/60] START max_features=0.5, min_samples_split=10, n_estimators=500..
# [CV 5/5; 30/60] END max_features=0.5, min_samples_split=10, n_estimators=500;, score=-0.522 total time=53.8min
# [CV 1/5; 31/60] START max_features=0.8, min_samples_split=1, n_estimators=25....
# [CV 1/5; 31/60] END max_features=0.8, min_samples_split=1, n_estimators=25;, score=-0.536 total time= 4.1min
# [CV 2/5; 31/60] START max_features=0.8, min_samples_split=1, n_estimators=25....
# [CV 2/5; 31/60] END max_features=0.8, min_samples_split=1, n_estimators=25;, score=-0.537 total time= 4.1min
# [CV 3/5; 31/60] START max_features=0.8, min_samples_split=1, n_estimators=25....
# [CV 3/5; 31/60] END max_features=0.8, min_samples_split=1, n_estimators=25;, score=-0.534 total time= 4.2min
# [CV 4/5; 31/60] START max_features=0.8, min_samples_split=1, n_estimators=25....
# [CV 4/5; 31/60] END max_features=0.8, min_samples_split=1, n_estimators=25;, score=-0.537 total time= 4.1min
# [CV 5/5; 31/60] START max_features=0.8, min_samples_split=1, n_estimators=25....
# [CV 5/5; 31/60] END max_features=0.8, min_samples_split=1, n_estimators=25;, score=-0.538 total time= 4.1min
# [CV 1/5; 32/60] START max_features=0.8, min_samples_split=1, n_estimators=50....
# [CV 1/5; 32/60] END max_features=0.8, min_samples_split=1, n_estimators=50;, score=-0.534 total time= 8.3min
# [CV 2/5; 32/60] START max_features=0.8, min_samples_split=1, n_estimators=50....
# [CV 2/5; 32/60] END max_features=0.8, min_samples_split=1, n_estimators=50;, score=-0.535 total time= 8.2min
# [CV 3/5; 32/60] START max_features=0.8, min_samples_split=1, n_estimators=50....
# [CV 3/5; 32/60] END max_features=0.8, min_samples_split=1, n_estimators=50;, score=-0.531 total time= 8.2min
# [CV 4/5; 32/60] START max_features=0.8, min_samples_split=1, n_estimators=50....
# [CV 4/5; 32/60] END max_features=0.8, min_samples_split=1, n_estimators=50;, score=-0.536 total time= 8.2min
# [CV 5/5; 32/60] START max_features=0.8, min_samples_split=1, n_estimators=50....
# [CV 5/5; 32/60] END max_features=0.8, min_samples_split=1, n_estimators=50;, score=-0.536 total time= 8.2min
# [CV 1/5; 33/60] START max_features=0.8, min_samples_split=1, n_estimators=100...
# [CV 1/5; 33/60] END max_features=0.8, min_samples_split=1, n_estimators=100;, score=-0.534 total time=16.4min
# [CV 2/5; 33/60] START max_features=0.8, min_samples_split=1, n_estimators=100...
# [CV 2/5; 33/60] END max_features=0.8, min_samples_split=1, n_estimators=100;, score=-0.534 total time=16.3min
# [CV 3/5; 33/60] START max_features=0.8, min_samples_split=1, n_estimators=100...
# [CV 3/5; 33/60] END max_features=0.8, min_samples_split=1, n_estimators=100;, score=-0.531 total time=16.3min
# [CV 4/5; 33/60] START max_features=0.8, min_samples_split=1, n_estimators=100...
# [CV 4/5; 33/60] END max_features=0.8, min_samples_split=1, n_estimators=100;, score=-0.535 total time=16.3min
# [CV 5/5; 33/60] START max_features=0.8, min_samples_split=1, n_estimators=100...
# [CV 5/5; 33/60] END max_features=0.8, min_samples_split=1, n_estimators=100;, score=-0.535 total time=16.5min
# [CV 1/5; 34/60] START max_features=0.8, min_samples_split=1, n_estimators=200...
# [CV 1/5; 34/60] END max_features=0.8, min_samples_split=1, n_estimators=200;, score=-0.533 total time=32.6min
# [CV 2/5; 34/60] START max_features=0.8, min_samples_split=1, n_estimators=200...
# [CV 2/5; 34/60] END max_features=0.8, min_samples_split=1, n_estimators=200;, score=-0.533 total time=32.8min
# [CV 3/5; 34/60] START max_features=0.8, min_samples_split=1, n_estimators=200...
# [CV 3/5; 34/60] END max_features=0.8, min_samples_split=1, n_estimators=200;, score=-0.530 total time=32.7min
# [CV 4/5; 34/60] START max_features=0.8, min_samples_split=1, n_estimators=200...
# [CV 4/5; 34/60] END max_features=0.8, min_samples_split=1, n_estimators=200;, score=-0.535 total time=32.9min
# [CV 5/5; 34/60] START max_features=0.8, min_samples_split=1, n_estimators=200...
# [CV 5/5; 34/60] END max_features=0.8, min_samples_split=1, n_estimators=200;, score=-0.534 total time=32.7min
# [CV 1/5; 35/60] START max_features=0.8, min_samples_split=1, n_estimators=500...
# [CV 1/5; 35/60] END max_features=0.8, min_samples_split=1, n_estimators=500;, score=-0.533 total time=81.3min
# [CV 2/5; 35/60] START max_features=0.8, min_samples_split=1, n_estimators=500...
# [CV 2/5; 35/60] END max_features=0.8, min_samples_split=1, n_estimators=500;, score=-0.533 total time=82.4min
# [CV 3/5; 35/60] START max_features=0.8, min_samples_split=1, n_estimators=500...
# [CV 3/5; 35/60] END max_features=0.8, min_samples_split=1, n_estimators=500;, score=-0.530 total time=83.8min
# [CV 4/5; 35/60] START max_features=0.8, min_samples_split=1, n_estimators=500...
# [CV 4/5; 35/60] END max_features=0.8, min_samples_split=1, n_estimators=500;, score=-0.534 total time=81.6min
# [CV 5/5; 35/60] START max_features=0.8, min_samples_split=1, n_estimators=500...
# [CV 5/5; 35/60] END max_features=0.8, min_samples_split=1, n_estimators=500;, score=-0.534 total time=82.4min
# [CV 1/5; 36/60] START max_features=0.8, min_samples_split=5, n_estimators=25....
# [CV 1/5; 36/60] END max_features=0.8, min_samples_split=5, n_estimators=25;, score=-0.528 total time= 4.1min
# [CV 2/5; 36/60] START max_features=0.8, min_samples_split=5, n_estimators=25....
# [CV 2/5; 36/60] END max_features=0.8, min_samples_split=5, n_estimators=25;, score=-0.528 total time= 4.0min
# [CV 3/5; 36/60] START max_features=0.8, min_samples_split=5, n_estimators=25....
# [CV 3/5; 36/60] END max_features=0.8, min_samples_split=5, n_estimators=25;, score=-0.526 total time= 4.0min
# [CV 4/5; 36/60] START max_features=0.8, min_samples_split=5, n_estimators=25....
# [CV 4/5; 36/60] END max_features=0.8, min_samples_split=5, n_estimators=25;, score=-0.530 total time= 4.1min
# [CV 5/5; 36/60] START max_features=0.8, min_samples_split=5, n_estimators=25....
# [CV 5/5; 36/60] END max_features=0.8, min_samples_split=5, n_estimators=25;, score=-0.529 total time= 4.0min
# [CV 1/5; 37/60] START max_features=0.8, min_samples_split=5, n_estimators=50....
# [CV 1/5; 37/60] END max_features=0.8, min_samples_split=5, n_estimators=50;, score=-0.527 total time= 8.0min
# [CV 2/5; 37/60] START max_features=0.8, min_samples_split=5, n_estimators=50....
# [CV 2/5; 37/60] END max_features=0.8, min_samples_split=5, n_estimators=50;, score=-0.527 total time= 7.9min
# [CV 3/5; 37/60] START max_features=0.8, min_samples_split=5, n_estimators=50....
# [CV 3/5; 37/60] END max_features=0.8, min_samples_split=5, n_estimators=50;, score=-0.524 total time= 8.0min
# [CV 4/5; 37/60] START max_features=0.8, min_samples_split=5, n_estimators=50....
# [CV 4/5; 37/60] END max_features=0.8, min_samples_split=5, n_estimators=50;, score=-0.528 total time= 8.0min
# [CV 5/5; 37/60] START max_features=0.8, min_samples_split=5, n_estimators=50....
# [CV 5/5; 37/60] END max_features=0.8, min_samples_split=5, n_estimators=50;, score=-0.528 total time= 8.0min
# [CV 1/5; 38/60] START max_features=0.8, min_samples_split=5, n_estimators=100...
# [CV 1/5; 38/60] END max_features=0.8, min_samples_split=5, n_estimators=100;, score=-0.526 total time=16.0min
# [CV 2/5; 38/60] START max_features=0.8, min_samples_split=5, n_estimators=100...
# [CV 2/5; 38/60] END max_features=0.8, min_samples_split=5, n_estimators=100;, score=-0.527 total time=15.9min
# [CV 3/5; 38/60] START max_features=0.8, min_samples_split=5, n_estimators=100...
# [CV 3/5; 38/60] END max_features=0.8, min_samples_split=5, n_estimators=100;, score=-0.523 total time=16.1min
# [CV 4/5; 38/60] START max_features=0.8, min_samples_split=5, n_estimators=100...
# [CV 4/5; 38/60] END max_features=0.8, min_samples_split=5, n_estimators=100;, score=-0.528 total time=16.0min
# [CV 5/5; 38/60] START max_features=0.8, min_samples_split=5, n_estimators=100...
# [CV 5/5; 38/60] END max_features=0.8, min_samples_split=5, n_estimators=100;, score=-0.527 total time=16.1min
# [CV 1/5; 39/60] START max_features=0.8, min_samples_split=5, n_estimators=200...
# [CV 1/5; 39/60] END max_features=0.8, min_samples_split=5, n_estimators=200;, score=-0.526 total time=32.0min
# [CV 2/5; 39/60] START max_features=0.8, min_samples_split=5, n_estimators=200...
# [CV 2/5; 39/60] END max_features=0.8, min_samples_split=5, n_estimators=200;, score=-0.526 total time=32.0min
# [CV 3/5; 39/60] START max_features=0.8, min_samples_split=5, n_estimators=200...
# [CV 3/5; 39/60] END max_features=0.8, min_samples_split=5, n_estimators=200;, score=-0.523 total time=32.0min
# [CV 4/5; 39/60] START max_features=0.8, min_samples_split=5, n_estimators=200...
# [CV 4/5; 39/60] END max_features=0.8, min_samples_split=5, n_estimators=200;, score=-0.527 total time=32.0min
# [CV 5/5; 39/60] START max_features=0.8, min_samples_split=5, n_estimators=200...
# [CV 5/5; 39/60] END max_features=0.8, min_samples_split=5, n_estimators=200;, score=-0.527 total time=31.9min
# [CV 1/5; 40/60] START max_features=0.8, min_samples_split=5, n_estimators=500...
# [CV 1/5; 40/60] END max_features=0.8, min_samples_split=5, n_estimators=500;, score=-0.526 total time=79.2min
# [CV 2/5; 40/60] START max_features=0.8, min_samples_split=5, n_estimators=500...
# [CV 2/5; 40/60] END max_features=0.8, min_samples_split=5, n_estimators=500;, score=-0.526 total time=79.0min
# [CV 3/5; 40/60] START max_features=0.8, min_samples_split=5, n_estimators=500...
# [CV 3/5; 40/60] END max_features=0.8, min_samples_split=5, n_estimators=500;, score=-0.522 total time=80.5min
# [CV 4/5; 40/60] START max_features=0.8, min_samples_split=5, n_estimators=500...
# [CV 4/5; 40/60] END max_features=0.8, min_samples_split=5, n_estimators=500;, score=-0.527 total time=79.9min
# [CV 5/5; 40/60] START max_features=0.8, min_samples_split=5, n_estimators=500...
# [CV 5/5; 40/60] END max_features=0.8, min_samples_split=5, n_estimators=500;, score=-0.527 total time=80.1min
# [CV 1/5; 41/60] START max_features=0.8, min_samples_split=10, n_estimators=25...
# [CV 1/5; 41/60] END max_features=0.8, min_samples_split=10, n_estimators=25;, score=-0.523 total time= 4.0min
# [CV 2/5; 41/60] START max_features=0.8, min_samples_split=10, n_estimators=25...
# [CV 2/5; 41/60] END max_features=0.8, min_samples_split=10, n_estimators=25;, score=-0.524 total time= 4.2min
# [CV 3/5; 41/60] START max_features=0.8, min_samples_split=10, n_estimators=25...
# [CV 3/5; 41/60] END max_features=0.8, min_samples_split=10, n_estimators=25;, score=-0.520 total time= 4.2min
# [CV 4/5; 41/60] START max_features=0.8, min_samples_split=10, n_estimators=25...
# [CV 4/5; 41/60] END max_features=0.8, min_samples_split=10, n_estimators=25;, score=-0.525 total time= 4.3min
# [CV 5/5; 41/60] START max_features=0.8, min_samples_split=10, n_estimators=25...
# [CV 5/5; 41/60] END max_features=0.8, min_samples_split=10, n_estimators=25;, score=-0.525 total time= 4.2min
# [CV 1/5; 42/60] START max_features=0.8, min_samples_split=10, n_estimators=50...
# [CV 1/5; 42/60] END max_features=0.8, min_samples_split=10, n_estimators=50;, score=-0.522 total time= 8.0min
# [CV 2/5; 42/60] START max_features=0.8, min_samples_split=10, n_estimators=50...
# [CV 2/5; 42/60] END max_features=0.8, min_samples_split=10, n_estimators=50;, score=-0.522 total time= 7.9min
# [CV 3/5; 42/60] START max_features=0.8, min_samples_split=10, n_estimators=50...
# [CV 3/5; 42/60] END max_features=0.8, min_samples_split=10, n_estimators=50;, score=-0.518 total time= 8.0min
# [CV 4/5; 42/60] START max_features=0.8, min_samples_split=10, n_estimators=50...
# [CV 4/5; 42/60] END max_features=0.8, min_samples_split=10, n_estimators=50;, score=-0.524 total time= 8.0min
# [CV 5/5; 42/60] START max_features=0.8, min_samples_split=10, n_estimators=50...
# [CV 5/5; 42/60] END max_features=0.8, min_samples_split=10, n_estimators=50;, score=-0.523 total time= 7.9min
# [CV 1/5; 43/60] START max_features=0.8, min_samples_split=10, n_estimators=100..
# [CV 1/5; 43/60] END max_features=0.8, min_samples_split=10, n_estimators=100;, score=-0.521 total time=15.7min
# [CV 2/5; 43/60] START max_features=0.8, min_samples_split=10, n_estimators=100..
# [CV 2/5; 43/60] END max_features=0.8, min_samples_split=10, n_estimators=100;, score=-0.522 total time=15.8min
# [CV 3/5; 43/60] START max_features=0.8, min_samples_split=10, n_estimators=100..
# [CV 3/5; 43/60] END max_features=0.8, min_samples_split=10, n_estimators=100;, score=-0.518 total time=15.9min
# [CV 4/5; 43/60] START max_features=0.8, min_samples_split=10, n_estimators=100..
# [CV 4/5; 43/60] END max_features=0.8, min_samples_split=10, n_estimators=100;, score=-0.524 total time=15.8min
# [CV 5/5; 43/60] START max_features=0.8, min_samples_split=10, n_estimators=100..
# [CV 5/5; 43/60] END max_features=0.8, min_samples_split=10, n_estimators=100;, score=-0.523 total time=16.1min
# [CV 1/5; 44/60] START max_features=0.8, min_samples_split=10, n_estimators=200..
# [CV 1/5; 44/60] END max_features=0.8, min_samples_split=10, n_estimators=200;, score=-0.521 total time=32.3min
# [CV 2/5; 44/60] START max_features=0.8, min_samples_split=10, n_estimators=200..
# [CV 2/5; 44/60] END max_features=0.8, min_samples_split=10, n_estimators=200;, score=-0.522 total time=32.2min
# [CV 3/5; 44/60] START max_features=0.8, min_samples_split=10, n_estimators=200..
# [CV 3/5; 44/60] END max_features=0.8, min_samples_split=10, n_estimators=200;, score=-0.518 total time=32.2min
# [CV 4/5; 44/60] START max_features=0.8, min_samples_split=10, n_estimators=200..
# [CV 4/5; 44/60] END max_features=0.8, min_samples_split=10, n_estimators=200;, score=-0.523 total time=32.3min
# [CV 5/5; 44/60] START max_features=0.8, min_samples_split=10, n_estimators=200..
# [CV 5/5; 44/60] END max_features=0.8, min_samples_split=10, n_estimators=200;, score=-0.522 total time=32.9min
# [CV 1/5; 45/60] START max_features=0.8, min_samples_split=10, n_estimators=500..
# [CV 1/5; 45/60] END max_features=0.8, min_samples_split=10, n_estimators=500;, score=-0.521 total time=81.7min
# [CV 2/5; 45/60] START max_features=0.8, min_samples_split=10, n_estimators=500..
# [CV 2/5; 45/60] END max_features=0.8, min_samples_split=10, n_estimators=500;, score=-0.521 total time=81.9min
# [CV 3/5; 45/60] START max_features=0.8, min_samples_split=10, n_estimators=500..
# [CV 3/5; 45/60] END max_features=0.8, min_samples_split=10, n_estimators=500;, score=-0.518 total time=81.6min
# [CV 4/5; 45/60] START max_features=0.8, min_samples_split=10, n_estimators=500..
# [CV 4/5; 45/60] END max_features=0.8, min_samples_split=10, n_estimators=500;, score=-0.523 total time=81.0min
# [CV 5/5; 45/60] START max_features=0.8, min_samples_split=10, n_estimators=500..
# [CV 5/5; 45/60] END max_features=0.8, min_samples_split=10, n_estimators=500;, score=-0.522 total time=81.6min
# [CV 1/5; 46/60] START max_features=1.0, min_samples_split=1, n_estimators=25....
# [CV 1/5; 46/60] END max_features=1.0, min_samples_split=1, n_estimators=25;, score=-0.537 total time= 5.3min
# [CV 2/5; 46/60] START max_features=1.0, min_samples_split=1, n_estimators=25....
# [CV 2/5; 46/60] END max_features=1.0, min_samples_split=1, n_estimators=25;, score=-0.537 total time= 5.2min
# [CV 3/5; 46/60] START max_features=1.0, min_samples_split=1, n_estimators=25....
# [CV 3/5; 46/60] END max_features=1.0, min_samples_split=1, n_estimators=25;, score=-0.535 total time= 5.1min
# [CV 4/5; 46/60] START max_features=1.0, min_samples_split=1, n_estimators=25....
# [CV 4/5; 46/60] END max_features=1.0, min_samples_split=1, n_estimators=25;, score=-0.539 total time= 5.2min
# [CV 5/5; 46/60] START max_features=1.0, min_samples_split=1, n_estimators=25....
# [CV 5/5; 46/60] END max_features=1.0, min_samples_split=1, n_estimators=25;, score=-0.539 total time= 5.2min
# [CV 1/5; 47/60] START max_features=1.0, min_samples_split=1, n_estimators=50....
# [CV 1/5; 47/60] END max_features=1.0, min_samples_split=1, n_estimators=50;, score=-0.536 total time=10.4min
# [CV 2/5; 47/60] START max_features=1.0, min_samples_split=1, n_estimators=50....
# [CV 2/5; 47/60] END max_features=1.0, min_samples_split=1, n_estimators=50;, score=-0.535 total time=10.3min
# [CV 3/5; 47/60] START max_features=1.0, min_samples_split=1, n_estimators=50....
# [CV 3/5; 47/60] END max_features=1.0, min_samples_split=1, n_estimators=50;, score=-0.533 total time=10.7min
# [CV 4/5; 47/60] START max_features=1.0, min_samples_split=1, n_estimators=50....
# [CV 4/5; 47/60] END max_features=1.0, min_samples_split=1, n_estimators=50;, score=-0.537 total time=10.8min
# [CV 5/5; 47/60] START max_features=1.0, min_samples_split=1, n_estimators=50....
# [CV 5/5; 47/60] END max_features=1.0, min_samples_split=1, n_estimators=50;, score=-0.537 total time=10.5min
# [CV 1/5; 48/60] START max_features=1.0, min_samples_split=1, n_estimators=100...
# [CV 1/5; 48/60] END max_features=1.0, min_samples_split=1, n_estimators=100;, score=-0.535 total time=21.0min
# [CV 2/5; 48/60] START max_features=1.0, min_samples_split=1, n_estimators=100...
# [CV 2/5; 48/60] END max_features=1.0, min_samples_split=1, n_estimators=100;, score=-0.535 total time=21.1min
# [CV 3/5; 48/60] START max_features=1.0, min_samples_split=1, n_estimators=100...
# [CV 3/5; 48/60] END max_features=1.0, min_samples_split=1, n_estimators=100;, score=-0.532 total time=20.6min
# [CV 4/5; 48/60] START max_features=1.0, min_samples_split=1, n_estimators=100...
# [CV 4/5; 48/60] END max_features=1.0, min_samples_split=1, n_estimators=100;, score=-0.536 total time=20.6min
# [CV 5/5; 48/60] START max_features=1.0, min_samples_split=1, n_estimators=100...
# [CV 5/5; 48/60] END max_features=1.0, min_samples_split=1, n_estimators=100;, score=-0.536 total time=20.9min
# [CV 1/5; 49/60] START max_features=1.0, min_samples_split=1, n_estimators=200...
# [CV 1/5; 49/60] END max_features=1.0, min_samples_split=1, n_estimators=200;, score=-0.535 total time=41.3min
# [CV 2/5; 49/60] START max_features=1.0, min_samples_split=1, n_estimators=200...
# [CV 2/5; 49/60] END max_features=1.0, min_samples_split=1, n_estimators=200;, score=-0.534 total time=41.4min
# [CV 3/5; 49/60] START max_features=1.0, min_samples_split=1, n_estimators=200...
# [CV 3/5; 49/60] END max_features=1.0, min_samples_split=1, n_estimators=200;, score=-0.531 total time=45.0min
# [CV 4/5; 49/60] START max_features=1.0, min_samples_split=1, n_estimators=200...
# [CV 4/5; 49/60] END max_features=1.0, min_samples_split=1, n_estimators=200;, score=-0.535 total time=41.6min
# [CV 5/5; 49/60] START max_features=1.0, min_samples_split=1, n_estimators=200...
# [CV 5/5; 49/60] END max_features=1.0, min_samples_split=1, n_estimators=200;, score=-0.536 total time=41.4min
# [CV 1/5; 50/60] START max_features=1.0, min_samples_split=1, n_estimators=500...
# [CV 1/5; 50/60] END max_features=1.0, min_samples_split=1, n_estimators=500;, score=-0.535 total time=102.9min
# [CV 2/5; 50/60] START max_features=1.0, min_samples_split=1, n_estimators=500...
# [CV 2/5; 50/60] END max_features=1.0, min_samples_split=1, n_estimators=500;, score=-0.534 total time=103.2min
# [CV 3/5; 50/60] START max_features=1.0, min_samples_split=1, n_estimators=500...
# [CV 3/5; 50/60] END max_features=1.0, min_samples_split=1, n_estimators=500;, score=-0.531 total time=104.9min
# [CV 4/5; 50/60] START max_features=1.0, min_samples_split=1, n_estimators=500...
# [CV 4/5; 50/60] END max_features=1.0, min_samples_split=1, n_estimators=500;, score=-0.535 total time=102.6min
# [CV 5/5; 50/60] START max_features=1.0, min_samples_split=1, n_estimators=500...
# [CV 5/5; 50/60] END max_features=1.0, min_samples_split=1, n_estimators=500;, score=-0.535 total time=103.2min
# [CV 1/5; 51/60] START max_features=1.0, min_samples_split=5, n_estimators=25....
# [CV 1/5; 51/60] END max_features=1.0, min_samples_split=5, n_estimators=25;, score=-0.529 total time= 5.0min
# [CV 2/5; 51/60] START max_features=1.0, min_samples_split=5, n_estimators=25....
# [CV 2/5; 51/60] END max_features=1.0, min_samples_split=5, n_estimators=25;, score=-0.530 total time= 5.0min
# [CV 3/5; 51/60] START max_features=1.0, min_samples_split=5, n_estimators=25....
# [CV 3/5; 51/60] END max_features=1.0, min_samples_split=5, n_estimators=25;, score=-0.528 total time= 5.2min
# [CV 4/5; 51/60] START max_features=1.0, min_samples_split=5, n_estimators=25....
# [CV 4/5; 51/60] END max_features=1.0, min_samples_split=5, n_estimators=25;, score=-0.531 total time= 5.5min
# [CV 5/5; 51/60] START max_features=1.0, min_samples_split=5, n_estimators=25....
# [CV 5/5; 51/60] END max_features=1.0, min_samples_split=5, n_estimators=25;, score=-0.532 total time= 5.1min
# [CV 1/5; 52/60] START max_features=1.0, min_samples_split=5, n_estimators=50....
# [CV 1/5; 52/60] END max_features=1.0, min_samples_split=5, n_estimators=50;, score=-0.528 total time=10.2min
# [CV 2/5; 52/60] START max_features=1.0, min_samples_split=5, n_estimators=50....
# [CV 2/5; 52/60] END max_features=1.0, min_samples_split=5, n_estimators=50;, score=-0.528 total time=10.4min
# [CV 3/5; 52/60] START max_features=1.0, min_samples_split=5, n_estimators=50....
# [CV 3/5; 52/60] END max_features=1.0, min_samples_split=5, n_estimators=50;, score=-0.525 total time=10.4min
# [CV 4/5; 52/60] START max_features=1.0, min_samples_split=5, n_estimators=50....
# [CV 4/5; 52/60] END max_features=1.0, min_samples_split=5, n_estimators=50;, score=-0.530 total time=10.2min
# [CV 5/5; 52/60] START max_features=1.0, min_samples_split=5, n_estimators=50....
# [CV 5/5; 52/60] END max_features=1.0, min_samples_split=5, n_estimators=50;, score=-0.530 total time=10.2min
# [CV 1/5; 53/60] START max_features=1.0, min_samples_split=5, n_estimators=100...
# [CV 1/5; 53/60] END max_features=1.0, min_samples_split=5, n_estimators=100;, score=-0.528 total time=20.7min
# [CV 2/5; 53/60] START max_features=1.0, min_samples_split=5, n_estimators=100...
# [CV 2/5; 53/60] END max_features=1.0, min_samples_split=5, n_estimators=100;, score=-0.528 total time=20.5min
# [CV 3/5; 53/60] START max_features=1.0, min_samples_split=5, n_estimators=100...
# [CV 3/5; 53/60] END max_features=1.0, min_samples_split=5, n_estimators=100;, score=-0.525 total time=20.4min
# [CV 4/5; 53/60] START max_features=1.0, min_samples_split=5, n_estimators=100...
# [CV 4/5; 53/60] END max_features=1.0, min_samples_split=5, n_estimators=100;, score=-0.529 total time=21.1min
# [CV 5/5; 53/60] START max_features=1.0, min_samples_split=5, n_estimators=100...
# [CV 5/5; 53/60] END max_features=1.0, min_samples_split=5, n_estimators=100;, score=-0.529 total time=20.7min
# [CV 1/5; 54/60] START max_features=1.0, min_samples_split=5, n_estimators=200...
# [CV 1/5; 54/60] END max_features=1.0, min_samples_split=5, n_estimators=200;, score=-0.527 total time=41.4min
# [CV 2/5; 54/60] START max_features=1.0, min_samples_split=5, n_estimators=200...
# [CV 2/5; 54/60] END max_features=1.0, min_samples_split=5, n_estimators=200;, score=-0.527 total time=41.3min
# [CV 3/5; 54/60] START max_features=1.0, min_samples_split=5, n_estimators=200...
# [CV 3/5; 54/60] END max_features=1.0, min_samples_split=5, n_estimators=200;, score=-0.525 total time=41.9min
# [CV 4/5; 54/60] START max_features=1.0, min_samples_split=5, n_estimators=200...
# [CV 4/5; 54/60] END max_features=1.0, min_samples_split=5, n_estimators=200;, score=-0.529 total time=41.4min
# [CV 5/5; 54/60] START max_features=1.0, min_samples_split=5, n_estimators=200...
# [CV 5/5; 54/60] END max_features=1.0, min_samples_split=5, n_estimators=200;, score=-0.529 total time=41.5min
# [CV 1/5; 55/60] START max_features=1.0, min_samples_split=5, n_estimators=500...
# [CV 1/5; 55/60] END max_features=1.0, min_samples_split=5, n_estimators=500;, score=-0.527 total time=103.6min
# [CV 2/5; 55/60] START max_features=1.0, min_samples_split=5, n_estimators=500...
# [CV 2/5; 55/60] END max_features=1.0, min_samples_split=5, n_estimators=500;, score=-0.527 total time=103.6min
# [CV 3/5; 55/60] START max_features=1.0, min_samples_split=5, n_estimators=500...
# [CV 3/5; 55/60] END max_features=1.0, min_samples_split=5, n_estimators=500;, score=-0.524 total time=102.1min
# [CV 4/5; 55/60] START max_features=1.0, min_samples_split=5, n_estimators=500...

# %%
hyp_search.best_params_

hyp_search.best_score_

# %%
hyp_search.best_estimator_

# %%
hyp_search.best_index_

# %%
hyp_search.scorer_(squared = True)
